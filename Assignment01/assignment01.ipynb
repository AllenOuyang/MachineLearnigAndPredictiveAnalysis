# %%
import pandas as pd
import numpy as np
import os
from sklearn.linear_model import LinearRegression
from sklearn.decomposition import PCA

# %%
# define the path of data
data_path = "/Users/allenouyang/jupyter/2023Sprint ML&PA(MSU)/Assignment01"
data = pd.read_csv(os.path.join(data_path, "test_sample.csv"))

# %%
data.head()
# Out:
#             Y        X1        X2        X3        X4        X5        X6  \
# 0  124.435513 -0.697402  0.846188 -0.198017  3.640837  0.312387  0.597385
# 1   85.368509  0.642218  1.454579  1.189507  3.038361  2.193394  0.974023
# 2   70.710269  0.345726 -0.444066  1.783675 -2.738523 -0.883935  0.364597
# 3   27.244978  0.995812  1.275795  3.099169 -0.938537 -4.455187  2.234666
# 4   -6.289899  2.096078  1.313942  0.011519 -0.405996 -3.134206 -0.292200
#
#          X7        X8        X9  ...      X482      X483      X484      X485  \
# 0  0.919800 -1.220830  0.569018  ...  2.931021 -3.582555  0.576870 -0.984742
# 1  1.501329  0.116019 -2.550714  ... -1.557638  0.681119  0.572481  0.568548
# 2  0.387007  0.527372 -0.710213  ... -0.545800 -2.638558  0.421229 -2.605670
# 3 -5.487220 -5.782001  0.573815  ...  2.001109  0.598511  1.702923 -0.055112
# 4 -3.293223  2.044410  2.739734  ... -1.038775  0.165643  3.939183 -2.009441
#
#        X486      X487      X488      X489      X490      X491
# 0 -3.069711  3.132093 -1.015533  3.554728  0.958477 -1.988799
# 1 -1.377704  0.292458  2.583286  1.040345 -0.676067  0.307844
# 2 -3.608689  1.936704 -1.890411 -2.360885  1.147250 -0.814404
# 3 -3.025544 -2.562918 -0.744016 -1.868171 -2.132322 -1.624889
# 4 -2.041372  0.250716  1.524316  2.480863 -2.125446 -2.550693
#
# [5 rows x 492 columns]

# %%
# Split data into X and Y
X = data.iloc[:,1:]
Y = data.iloc[:,0]

# Initialize variables
r2 = []
n_orig = None

# Fit linear regression models with increasing number of regressors
for i in range(1, len(X.columns)+1):
    lin_reg = LinearRegression()
    lin_reg.fit(X.iloc[:,:i], Y)
    r2.append(lin_reg.score(X.iloc[:,:i], Y))
    if n_orig is None and r2[-1] > 0.9:
        n_orig = i
        
# Print results
print("Smallest number of regressors making determination coefficient greater than 0.9: ", n_orig)
# Out:
# Smallest number of regressors making determination coefficient greater than 0.9:  326

# %%
# Fit PCA on the data
pca = PCA()
X_PCA = pca.fit_transform(X)

# Calculate explained variance ratio for each component
variance_ratio = pca.explained_variance_ratio_

# Calculate cumulative explained variance ratio
cumulative_variance_ratio = np.cumsum(variance_ratio)
# Initialize variables
n_PCA = None
r2_PCA = []

# Find smallest number of PCA factors necessary for determination coefficient greater than 0.9
for i in range(1, n_orig+1):
    lin_reg = LinearRegression()
    lin_reg.fit(X_PCA[:,:i], Y)
    r2_PCA.append(lin_reg.score(X_PCA[:,:i], Y))
    if n_PCA is None and r2_PCA[-1] > 0.9:
        n_PCA = i
        break
        
# Print results
print("Smallest number of PCA factors necessary for determination coefficient greater than 0.9: ", n_PCA)
print("Determination coefficient for the model with n_PCA selected most important meta-features: ", r2_PCA[-1])
# Out:
# Smallest number of PCA factors necessary for determination coefficient greater than 0.9:  245
# Determination coefficient for the model with n_PCA selected most important meta-features:  0.906647676321508

# %%
print(r2_PCA)
print("Model dimensionality reduction:", n_orig - n_PCA)
print("Determination coefficient with selected PCA features:", r2_PCA[-1])
# Out:
